# %% [markdown]
# # 01 - Exploratory Data Analysis
#
# Dataset: [Pima Indians Diabetes Database](https://www.kaggle.com/datasets/uciml/pima-indians-diabetes-database) (National Institute of Diabetes and Digestive and Kidney Diseases).
#
# Goal: decide whether a patient has diabetes based on 8 diagnostic measurements. This notebook does a first structured pass over the raw data: shape, types, missing values, duplicates, and a column-type classification (categorical / numerical).

# %%
import sys
sys.path.append("..")

import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)
pd.set_option('display.width', 500)
pd.set_option('display.float_format', '{:.2f}'.format)

from src.eda import check_df, grab_col_names, check_missing_value

# %% [markdown]
# ## Load data

# %%
df = pd.read_csv("../data/diabetes.csv")
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  DiabetesPedigreeFunction  Age  Outcome
# 0            6      148             72             35        0 33.60                      0.63   50        1
# 1            1       85             66             29        0 26.60                      0.35   31        0
# 2            8      183             64              0        0 23.30                      0.67   32        1
# 3            1       89             66             23       94 28.10                      0.17   21        0
# 4            0      137             40             35      168 43.10                      2.29   33        1

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# ## First overview

# %%
check_df(df)
# Out:
# ****** Shape ******
# Shape     : (768, 9)
# Size      : 6912
# Dimension : 2
#
# ****** Types ******
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object
#
# ****** Head ******
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  DiabetesPedigreeFunction  Age  Outcome
# 0            6      148             72             35        0 33.60                      0.63   50        1
# 1            1       85             66             29        0 26.60                      0.35   31        0
# 2            8      183             64              0        0 23.30                      0.67   32        1
# ...

# %% [markdown]
# **Variables**
# 1. `Pregnancies` - number of times pregnant
# 2. `Glucose` - plasma glucose concentration (2h OGTT). <140 normal, 140-199 impaired, >=200 diabetes
# 3. `BloodPressure` - diastolic blood pressure (mm Hg)
# 4. `SkinThickness` - triceps skin fold thickness (mm)
# 5. `Insulin` - 2-hour post-prandial insulin (mu U/ml). <140 normal, 140-199 prediabetes, >=200 diabetes
# 6. `BMI` - body mass index
# 7. `DiabetesPedigreeFunction` - genetic influence proxy
# 8. `Age` (years)
# 9. `Outcome` - target (1 = diabetic, 0 = not diabetic)

# %% [markdown]
# ## Column type classification

# %%
cat_cols, num_cols, cat_but_car = grab_col_names(df)
# Out:
# Observations: 768
# Variables:    9
# cat_cols:     1
# num_cols:     8
# cat_but_car:  0
# num_but_cat:  1

# %% [markdown]
# ## Missing values (declared)

# %%
check_missing_value(df)
# Out:
# Empty DataFrame
# Columns: [n_miss, ratio]
# Index: []

# %% [markdown]
# There are no `NaN` values declared in the dataset. However, several columns have a minimum value of **0**, which is not physiologically possible (except for `Pregnancies`). This will be investigated and fixed in the next notebook (`02_preprocessing.ipynb`).

# %%
suspicious_cols = ["Glucose", "BloodPressure", "SkinThickness", "Insulin", "BMI"]
(df[suspicious_cols] == 0).sum()
# Out:
# Glucose            5
# BloodPressure     35
# SkinThickness    227
# Insulin          374
# BMI               11
# dtype: int64
